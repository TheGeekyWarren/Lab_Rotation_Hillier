# %%
import os
import cv2
import shutil
import deeplabcut
import numpy as np
import pandas as pd
import subprocess
from datetime import date
import math

# Converting .mov videos to .mp4
def conv_mp4(input_file):
    out_name = os.path.splitext(input_file)[0].lstrip('.') 
    print(out_name)
    output_file = out_name + '.mp4'

    # Run FFmpeg command to convert MOV to MP4
    command = f"ffmpeg -i {input_file} -c:v libx264 -preset medium -crf 23 -c:a aac -b:a 128k {output_file}"
    subprocess.call(command, shell=True)
    new = os.path.join(os.path.dirname(os.path.dirname(output_file)), 'Conv_vids', os.path.basename(output_file))
    shutil.move(output_file, new)


def downsize(path, to_path):
    dsv = deeplabcut.DownSampleVideo(path, width=1280, height=720)
    shutil.move(dsv, os.path.join(to_path, os.path.basename(dsv)))

#cropping video and Gamma correction
def gamma_correct(convid):
    
    # Load the video file
    video = cv2.VideoCapture(convid)

    # Get the frame rate and total number of frames
    fps = int(video.get(cv2.CAP_PROP_FPS))
    total_frames = int(video.get(cv2.CAP_PROP_FRAME_COUNT))

    #*********************************************
    # Set appropriate values for target average illumination of the frame
    target_br = 0.6

    #**********************************************
    
    target_g = math.log(target_br)
    
    # Set the video writer
    output_name = os.path.splitext(os.path.basename(convid))[0].lstrip('.') + '_AGC.mp4'
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    out = cv2.VideoWriter(output_name, fourcc, fps, (int(video.get(cv2.CAP_PROP_FRAME_WIDTH)), int(video.get(cv2.CAP_PROP_FRAME_HEIGHT))))
    start_frame = 0
    
    # Set the current frame number to the start frame
    video.set(cv2.CAP_PROP_POS_FRAMES, start_frame)
    frame_number = start_frame
    
    # Loop through the frames and write them to the output video
    for i in range(start_frame, total_frames):
        ret, frame = video.read()
        if not ret:
            break
        
        # Normalize the pixel values to the range [0, 1]
        frame_normalized = frame.astype(np.float32) / 255.0
        gray = cv2.cvtColor(frame_normalized, cv2.COLOR_BGR2GRAY)
        
        # Finding the mean luminance of the frame
        brightness = np.mean(frame_normalized)

        #finding and correcting gamma - a number is assigned to be the 'innate' gamma value of the frame, and that value is used to find the correction needed. 
        if brightness == 0:
            print('err')
            continue
        assigned_g = math.log(brightness)
        gamma = assigned_g/target_g

        # Apply gamma correction
        frame_corrected = np.power(frame_normalized, 1/gamma)

        # Scale the pixel values back to the range [0, 255]
        frame_scaled = (frame_corrected * 255.0).astype(np.uint8)
        
        print(round(frame_number/total_frames*100, 2), end = '\r')
        frame_number += 1
        # cv2.imshow('output', frame)
        # cv2.imshow('output', frame_scaled)
        out.write(frame_scaled)
    # new = os.path.join(os.path.dirname(os.path.dirname(convid)), 'GC_Conv_vids', os.path.basename(convid))
    # shutil.move(dsv, new)
    print("Done - ", convid)
    print('')
    # Release the video objects
    video.release()
    out.release()
    cv2.destroyAllWindows()


#Processing videos using DeepLabCut ModelZoo's pretrained model - Primate face
def process(fold, project_name, your_name):
    file = fold[0]
    print(file)
    bodyparts = ['RightEye_Outer', 'RightEye_Top', 'RightEye_Bottom', 'RightEye_Inner', 'RightEye_Pupil', 'LeftEye_Outer', 'LeftEye_Top', 'LeftEye_Bottom', 'LeftEye_Inner', 'LeftEye_Pupil',
                 'OutlineTop_Mid','RightNostrils_Top', 'RightNostrils_Bottom','LeftNostrils_Top', 'LeftNostrils_Bottom', 'NostrilsTop_Centre']
    videotype = os.path.splitext(file)[-1].lstrip('.')  # or MOV, or avi, whatever you uploaded!
    video_down = folder
    name_fold = 'Analyse_' + os.path.basename(os.path.dirname(file))
    
    model_options = deeplabcut.create_project.modelzoo.Modeloptions
    model_selection = 'primate_face'

    config_path, train_config_path = deeplabcut.create_pretrained_project(
        project_name,
        your_name,
        video_down,
        videotype=videotype,
        model=model_selection,
        analyzevideo=True,
        createlabeledvideo=False,
        copy_videos=False,
    )

    edits = {
        'dotsize': 1.5,  # size of the dots!--------------------------------------------------------------------------------------------------------------------------------
        'pcutoff': 0.4,  # the higher, the more conservative the plotting!
    }
    deeplabcut.auxiliaryfunctions.edit_config(config_path, edits)
    project_path = os.path.dirname(config_path)
    full_video_path = []
    for i in fold:
        full_video_path.append(os.path.join(project_path,'videos', os.path.basename(i)))

    # filter predictions (should already be done above ;):
    deeplabcut.filterpredictions(config_path, full_video_path, videotype=videotype)

    # re-create the video with your edits!
    # deeplabcut.CropVideo(config_path, full_video_path, 'crop', 
    deeplabcut.create_labeled_video(config_path, full_video_path, videotype=videotype, displayedbodyparts=bodyparts, draw_skeleton = True, filtered=True)

#Cropping the video based on confidence of facial features
def crop_it(feed):
    
    fl_pth, vid_pth, x = feed
    # deeplabcut.analyze_videos(config_path, 'CropGr.mp4', save_as_csv=True, dynamic=(True,.6,30))
    print("Starting Cropping")

    # Load tracking results generated by DeepLabCut
    tracking_data = pd.read_hdf(fl_pth)

    # Define the names of the facial features that you want to extract frames for
    feature_names = ['RightEye_Pupil','LeftEye_Pupil', 'NostrilsTop_Centre', 'OutlineTop_Mid']

    # Define the threshold for the confidence score of the facial features
    confidence_threshold = 0.9
    
    # Load the input video
    cap = cv2.VideoCapture(vid_pth)
    
    tot_frame = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    
    # Define the output video writer
    bn = os.path.basename(vid_pth).split('.')[0]
    out_file = 'Crpoutput_video' + bn + '.mp4'
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    out = cv2.VideoWriter(out_file, fourcc, 30, (int(cap.get(cv2.CAP_PROP_FRAME_WIDTH)), int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))))
    print("Output file written - ", out_file)

    # Loop through the video frames and extract frames with facial features
    frame_number = 0
    cap.set(cv2.CAP_PROP_POS_FRAMES, frame_number)
    while(cap.isOpened()):
        ret, frame = cap.read()
        if ret == True:
            # Get the tracking data for the current frame
            frame_data = tracking_data.loc[frame_number]

            # Check if the desired facial features are present in the frame
            feature_present = False
            check = 0
            for feature_name in feature_names:
                if feature_name in frame_data.loc[x] and frame_data.loc[x].loc[feature_name].loc['likelihood'] > confidence_threshold:
                    check += 1
            if check==4:
                feature_present = True

            # If the desired facial features are present, save the frame to the output video
            if feature_present: #check==4
                # cv2.imshow('output', frame)
                out.write(frame)
            # Display the output
            #cv2.imshow('output', frame)
            if cv2.waitKey(1) & 0xFF == ord('q'):
                break
            print(round(frame_number/tot_frame*100, 2), end = '\r')
            # Increment the frame number
            frame_number += 1
        else:
            break
    print("Done")
    # Release resources
    cap.release()
    out.release()
    cv2.destroyAllWindows()




#enter path of folder (including folder name) containing all your videos of interest------------------------------------------------------------------------------------------
vid_dir = '/home/yramakrishna/DeepLabCut/conda-environments/Codes/Videos_Calli'
#initializing project name and author's name ---------------------------------------------------------------------------------------------------------------------------------
project_name = 'DLC'
your_name = 'VK'

os.chdir(os.path.dirname(vid_dir))
print(os.getcwd())

#Create a new folder called All_vids in the current directory
if not os.path.exists('All_vids'):
        os.makedirs('All_vids')
os.chdir('All_vids')

to_dir = os.path.join(os.getcwd(), os.path.basename(vid_dir)) #moving the folderwith videos to the current directory
shutil.move(vid_dir, to_dir)

#Storing converted videos in a new folder
if not os.path.exists('Conv_vids'):
        os.makedirs('Conv_vids')
        
vid_dir_basename = os.path.basename(vid_dir)
        
#Converting files from mov to MP4 (if any)
for file in os.listdir(os.path.join(os.path.dirname(to_dir), vid_dir_basename)):
    path=os.path.join(os.path.join(os.path.dirname(to_dir), vid_dir_basename, file))
    if file.endswith(".mov"):
        conv_mp4(path)
    elif file.endswith(".mp4"):
        path2=os.path.join(os.path.join(os.path.dirname(to_dir), 'Conv_vids', file))
        shutil.copy(path, path2)

os.chdir(os.path.dirname(to_dir))

if not os.path.exists('Downsize_Conv_vids'):
        os.makedirs('Downsize_Conv_vids')
os.chdir('Downsize_Conv_vids')

# vid_names = []
for file in os.listdir(os.path.join(os.path.dirname(to_dir), 'Conv_vids')):
    if file.endswith(".mp4"):
        path=os.path.join(os.path.join(os.path.dirname(to_dir), 'Conv_vids', file))
        downsize(path, os.getcwd())

os.chdir(os.path.dirname(to_dir))

#Creae a folder for gamma corrected videos
if not os.path.exists('AGC_Conv_vids'):
        os.makedirs('AGC_Conv_vids')
os.chdir('AGC_Conv_vids')

#Applying gamma correction on the mp4 videos
for file in os.listdir(os.path.join(os.path.dirname(to_dir), 'Downsize_Conv_vids')):
    if file.endswith(".mp4"):
        path=os.path.join(os.path.join(os.path.dirname(to_dir), 'Downsize_Conv_vids', file))
        gamma_correct(path)
        
os.chdir('..')

#Compiling a list ofpaths for analysis
folder = [] 
for file in os.listdir(os.path.join(os.path.dirname(to_dir), 'AGC_Conv_vids')):
    if file.endswith(".mp4"):
        path=os.path.join(os.path.join(os.path.dirname(to_dir), 'AGC_Conv_vids', file))
        folder.append(path)



#Analyzing all videos with ModelZoo
process(folder, project_name, your_name)

#Collecting files with information on labels, as well as the labelled videos.
os.chdir(os.path.join(os.getcwd()))
h5files = []
vid_to_crop = []
today = str(date.today())
# today = "2023-04-12" -------------------------------------------------Modify if you created the modelzoo files on a different day than today.
proj_fold = project_name+'-'+your_name+'-'+today
target = os.path.join(os.getcwd(),proj_fold,'videos')
for file in os.listdir(target):
    if file.endswith("filtered.h5"):
        h5files.append(os.path.join(target,file))
for file in os.listdir(target):   
    if file.endswith("labeled.mp4"):
        vid_to_crop.append(os.path.join(target,file))


os.chdir(os.path.join(os.getcwd()))
if not os.path.exists('Cropped_vids'):
        os.makedirs('Cropped_vids')
os.chdir('Cropped_vids')

crop_source = []

if len(h5files)==len(vid_to_crop):
    for i in h5files:
        found = ''
        for j in vid_to_crop:
            x = os.path.splitext(i)[0].rstrip('_filtered.h5')
            y = os.path.splitext(j)[0].rstrip('filtered_labeled.mp4')
            if x==y:
                found = j
        k = os.path.basename(i)
        l = 'DLC' + k.split('DLC')[1] + 'DLC' + k.split('DLC')[2].rstrip('_filtered.h5')
        crop_source.append([i,found, l])

c_s = np.array(crop_source)

all_frames = []

for i in c_s:
    x = crop_it(i)
    all_frames.append([i[1],x])
# Out:
# 2023-07-06 16:19:43.734011: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-06 16:19:43.830710: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-07-06 16:19:44.145334: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/yramakrishna/anaconda3/lib/python3.9/site-packages/cv2/../../lib64:/usr/local/cuda/lib64:
# 2023-07-06 16:19:44.145378: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/yramakrishna/anaconda3/lib/python3.9/site-packages/cv2/../../lib64:/usr/local/cuda/lib64:
# 2023-07-06 16:19:44.145383: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# Loading DLC 2.3.3...
# /home/yramakrishna/DeepLabCut/conda-environments/Codes
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   WARNING: library configuration mismatch
#   avcodec     configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared --enable-version3 --disable-doc --disable-programs --enable-libaribb24 --enable-libopencore_amrnb --enable-libopencore_amrwb --enable-libtesseract --enable-libvo_amrwbenc --enable-libsmbclient
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/home/yramakrishna/DeepLabCut/conda-environments/Codes/All_vids/Conv_vids/S11b.mp4':
#   Metadata:
#     major_brand     : M4V
#     minor_version   : 1
#     compatible_brands: M4V mp42isom
#     creation_time   : 2019-12-02T10:33:34.000000Z
#   Duration: 00:00:03.84, start: 0.000000, bitrate: 4521 kb/s
#   Stream #0:0(eng): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709), 1920x1080 [SAR 10:11 DAR 160:99], 4505 kb/s, 59.94 fps, 59.94 tbr, 60k tbn, 119.88 tbc (default)
#     Metadata:
#       creation_time   : 2019-12-02T10:33:34.000000Z
#       handler_name    : Mainconcept MP4 Video Media Handler
#       vendor_id       : [0][0][0][0]
#       encoder         : AVC Coding
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x56101a31df00] using SAR=10/11
# [libx264 @ 0x56101a31df00] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x56101a31df00] profile High, level 3.2, 4:2:0, 8-bit
# [libx264 @ 0x56101a31df00] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=22 lookahead_threads=3 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '/home/yramakrishna/DeepLabCut/conda-environments/Codes/All_vids/Conv_vids/S11bdownsampled.mp4':
#   Metadata:
#     major_brand     : M4V
#     minor_version   : 1
#     compatible_brands: M4V mp42isom
#     encoder         : Lavf58.76.100
#   Stream #0:0(eng): Video: h264 (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1280x720 [SAR 10:11 DAR 160:99], q=2-31, 59.94 fps, 60k tbn (default)
#     Metadata:
#       creation_time   : 2019-12-02T10:33:34.000000Z
#       handler_name    : Mainconcept MP4 Video Media Handler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=  230 fps=0.0 q=-1.0 Lsize=     884kB time=00:00:03.78 bitrate=1912.7kbits/s speed=6.16x
# video:881kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.402747%
# [libx264 @ 0x56101a31df00] frame I:1     Avg QP:22.39  size: 69661
# [libx264 @ 0x56101a31df00] frame P:65    Avg QP:23.42  size: 11404
# [libx264 @ 0x56101a31df00] frame B:164   Avg QP:27.38  size:   550
# [libx264 @ 0x56101a31df00] consecutive B-frames:  2.2%  6.1%  6.5% 85.2%
# [libx264 @ 0x56101a31df00] mb I  I16..4:  9.9% 75.2% 14.8%
# [libx264 @ 0x56101a31df00] mb P  I16..4:  1.0%  4.3%  0.6%  P16..4: 32.1% 10.3%  6.0%  0.0%  0.0%    skip:45.6%
# [libx264 @ 0x56101a31df00] mb B  I16..4:  0.0%  0.0%  0.0%  B16..8: 14.9%  0.2%  0.0%  direct: 0.1%  skip:84.9%  L0:41.2% L1:57.2% BI: 1.6%
# [libx264 @ 0x56101a31df00] 8x8 transform intra:73.2% inter:77.1%
# [libx264 @ 0x56101a31df00] coded y,uvDC,uvAC intra: 59.8% 37.3% 5.7% inter: 5.4% 2.5% 0.0%
# [libx264 @ 0x56101a31df00] i16 v,h,dc,p: 29% 27%  7% 36%
# [libx264 @ 0x56101a31df00] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 17% 18% 17%  6%  9%  7% 10%  7%  8%
# [libx264 @ 0x56101a31df00] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 13% 21%  9%  6% 15%  7% 18%  5%  6%
# [libx264 @ 0x56101a31df00] i8c dc,h,v,p: 61% 15% 20%  4%
# [libx264 @ 0x56101a31df00] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x56101a31df00] ref P L0: 72.3% 14.2% 10.4%  3.2%
# [libx264 @ 0x56101a31df00] ref B L0: 91.1%  7.6%  1.3%
# [libx264 @ 0x56101a31df00] ref B L1: 97.8%  2.2%
# [libx264 @ 0x56101a31df00] kb/s:1878.71
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   WARNING: library configuration mismatch
#   avcodec     configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared --enable-version3 --disable-doc --disable-programs --enable-libaribb24 --enable-libopencore_amrnb --enable-libopencore_amrwb --enable-libtesseract --enable-libvo_amrwbenc --enable-libsmbclient
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/home/yramakrishna/DeepLabCut/conda-environments/Codes/All_vids/Conv_vids/S76b.mp4':
#   Metadata:
#     major_brand     : M4V
#     minor_version   : 1
#     compatible_brands: M4V mp42isom
#     creation_time   : 2019-12-06T05:04:14.000000Z
#   Duration: 00:00:04.43, start: 0.000000, bitrate: 4472 kb/s
#   Stream #0:0(eng): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709), 1280x720 [SAR 10:11 DAR 160:99], 4459 kb/s, 30 fps, 30 tbr, 30k tbn, 60 tbc (default)
#     Metadata:
#       creation_time   : 2019-12-06T05:04:14.000000Z
#       handler_name    : Mainconcept MP4 Video Media Handler
#       vendor_id       : [0][0][0][0]
#       encoder         : AVC Coding
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x563b1e3d1c40] using SAR=10/11
# [libx264 @ 0x563b1e3d1c40] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x563b1e3d1c40] profile High, level 3.1, 4:2:0, 8-bit
# [libx264 @ 0x563b1e3d1c40] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=22 lookahead_threads=3 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '/home/yramakrishna/DeepLabCut/conda-environments/Codes/All_vids/Conv_vids/S76bdownsampled.mp4':
#   Metadata:
#     major_brand     : M4V
#     minor_version   : 1
#     compatible_brands: M4V mp42isom
#     encoder         : Lavf58.76.100
#   Stream #0:0(eng): Video: h264 (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1280x720 [SAR 10:11 DAR 160:99], q=2-31, 30 fps, 15360 tbn (default)
#     Metadata:
#       creation_time   : 2019-12-06T05:04:14.000000Z
#       handler_name    : Mainconcept MP4 Video Media Handler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=  133 fps=0.0 q=-1.0 Lsize=     560kB time=00:00:04.33 bitrate=1058.3kbits/s speed=11.2x
# video:557kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.435394%
# [libx264 @ 0x563b1e3d1c40] frame I:1     Avg QP:20.43  size: 33715
# [libx264 @ 0x563b1e3d1c40] frame P:34    Avg QP:20.97  size: 13315
# [libx264 @ 0x563b1e3d1c40] frame B:98    Avg QP:19.84  size:   853
# [libx264 @ 0x563b1e3d1c40] consecutive B-frames:  0.8%  0.0%  9.0% 90.2%
# [libx264 @ 0x563b1e3d1c40] mb I  I16..4: 23.5% 66.5%  9.9%
# [libx264 @ 0x563b1e3d1c40] mb P  I16..4:  9.8% 16.7%  1.5%  P16..4: 29.6% 10.1%  3.7%  0.0%  0.0%    skip:28.6%
# [libx264 @ 0x563b1e3d1c40] mb B  I16..4:  0.2%  0.4%  0.0%  B16..8: 11.3%  0.4%  0.1%  direct: 1.1%  skip:86.5%  L0:49.6% L1:49.2% BI: 1.2%
# [libx264 @ 0x563b1e3d1c40] 8x8 transform intra:60.2% inter:78.6%
# [libx264 @ 0x563b1e3d1c40] coded y,uvDC,uvAC intra: 39.9% 41.6% 5.2% inter: 4.1% 5.8% 0.0%
# [libx264 @ 0x563b1e3d1c40] i16 v,h,dc,p: 29% 31%  7% 33%
# [libx264 @ 0x563b1e3d1c40] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 25% 18% 23%  5%  6%  6%  6%  6%  5%
# [libx264 @ 0x563b1e3d1c40] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 27% 19% 15%  5% 10%  8%  7%  5%  4%
# [libx264 @ 0x563b1e3d1c40] i8c dc,h,v,p: 56% 20% 20%  3%
# [libx264 @ 0x563b1e3d1c40] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x563b1e3d1c40] ref P L0: 69.7% 11.6% 12.3%  6.4%
# [libx264 @ 0x563b1e3d1c40] ref B L0: 90.8%  6.3%  2.9%
# [libx264 @ 0x563b1e3d1c40] ref B L1: 97.9%  2.1%
# [libx264 @ 0x563b1e3d1c40] kb/s:1028.67
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   WARNING: library configuration mismatch
#   avcodec     configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared --enable-version3 --disable-doc --disable-programs --enable-libaribb24 --enable-libopencore_amrnb --enable-libopencore_amrwb --enable-libtesseract --enable-libvo_amrwbenc --enable-libsmbclient
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/home/yramakrishna/DeepLabCut/conda-environments/Codes/All_vids/Conv_vids/S7a.mp4':
#   Metadata:
#     major_brand     : M4V
#     minor_version   : 1
#     compatible_brands: M4V mp42isom
#     creation_time   : 2019-12-04T09:52:48.000000Z
#   Duration: 00:00:01.07, start: 0.000000, bitrate: 4543 kb/s
#   Stream #0:0(eng): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709), 1280x720 [SAR 10:11 DAR 160:99], 4493 kb/s, 30 fps, 30 tbr, 30k tbn, 60 tbc (default)
#     Metadata:
#       creation_time   : 2019-12-04T09:52:48.000000Z
#       handler_name    : Mainconcept MP4 Video Media Handler
#       vendor_id       : [0][0][0][0]
#       encoder         : AVC Coding
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x55783a040ec0] using SAR=10/11
# [libx264 @ 0x55783a040ec0] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x55783a040ec0] profile High, level 3.1, 4:2:0, 8-bit
# [libx264 @ 0x55783a040ec0] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=22 lookahead_threads=3 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '/home/yramakrishna/DeepLabCut/conda-environments/Codes/All_vids/Conv_vids/S7adownsampled.mp4':
#   Metadata:
#     major_brand     : M4V
#     minor_version   : 1
#     compatible_brands: M4V mp42isom
#     encoder         : Lavf58.76.100
#   Stream #0:0(eng): Video: h264 (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1280x720 [SAR 10:11 DAR 160:99], q=2-31, 30 fps, 15360 tbn (default)
#     Metadata:
#       creation_time   : 2019-12-04T09:52:48.000000Z
#       handler_name    : Mainconcept MP4 Video Media Handler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=   32 fps=0.0 q=-1.0 Lsize=     527kB time=00:00:00.96 bitrate=4465.0kbits/s speed=3.63x
# video:526kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.235003%
# [libx264 @ 0x55783a040ec0] frame I:1     Avg QP:25.27  size: 40910
# [libx264 @ 0x55783a040ec0] frame P:14    Avg QP:25.39  size: 22462
# [libx264 @ 0x55783a040ec0] frame B:17    Avg QP:28.16  size: 10719
# [libx264 @ 0x55783a040ec0] consecutive B-frames: 25.0%  6.2% 18.8% 50.0%
# [libx264 @ 0x55783a040ec0] mb I  I16..4: 20.8% 54.3% 24.8%
# [libx264 @ 0x55783a040ec0] mb P  I16..4:  6.3% 16.4%  3.5%  P16..4: 36.7% 11.0%  2.9%  0.0%  0.0%    skip:23.2%
# [libx264 @ 0x55783a040ec0] mb B  I16..4:  1.5%  2.7%  0.8%  B16..8: 42.3%  9.4%  1.7%  direct: 2.0%  skip:39.7%  L0:58.0% L1:35.0% BI: 7.0%
# [libx264 @ 0x55783a040ec0] 8x8 transform intra:59.7% inter:74.6%
# [libx264 @ 0x55783a040ec0] coded y,uvDC,uvAC intra: 58.3% 32.3% 0.9% inter: 18.7% 5.8% 0.0%
# [libx264 @ 0x55783a040ec0] i16 v,h,dc,p: 24% 23%  5% 47%
# [libx264 @ 0x55783a040ec0] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 23% 20% 13%  8%  6%  6%  7%  9%  9%
# [libx264 @ 0x55783a040ec0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 19% 17% 13% 11% 10%  7%  7%  9%  7%
# [libx264 @ 0x55783a040ec0] i8c dc,h,v,p: 56% 20% 18%  6%
# [libx264 @ 0x55783a040ec0] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x55783a040ec0] ref P L0: 77.0% 11.2%  9.9%  1.9%
# [libx264 @ 0x55783a040ec0] ref B L0: 95.0%  4.7%  0.4%
# [libx264 @ 0x55783a040ec0] ref B L1: 98.0%  2.0%
# [libx264 @ 0x55783a040ec0] kb/s:4032.00
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   WARNING: library configuration mismatch
#   avcodec     configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared --enable-version3 --disable-doc --disable-programs --enable-libaribb24 --enable-libopencore_amrnb --enable-libopencore_amrwb --enable-libtesseract --enable-libvo_amrwbenc --enable-libsmbclient
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/home/yramakrishna/DeepLabCut/conda-environments/Codes/All_vids/Conv_vids/S11a.mp4':
#   Metadata:
#     major_brand     : M4V
#     minor_version   : 1
#     compatible_brands: M4V mp42isom
#     creation_time   : 2019-12-02T10:28:53.000000Z
#   Duration: 00:00:01.15, start: 0.000000, bitrate: 4514 kb/s
#   Stream #0:0(eng): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709), 1920x1080 [SAR 10:11 DAR 160:99], 4466 kb/s, 59.94 fps, 59.94 tbr, 60k tbn, 119.88 tbc (default)
#     Metadata:
#       creation_time   : 2019-12-02T10:28:53.000000Z
#       handler_name    : Mainconcept MP4 Video Media Handler
#       vendor_id       : [0][0][0][0]
#       encoder         : AVC Coding
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x559e085c0c00] using SAR=10/11
# [libx264 @ 0x559e085c0c00] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x559e085c0c00] profile High, level 3.2, 4:2:0, 8-bit
# [libx264 @ 0x559e085c0c00] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=22 lookahead_threads=3 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '/home/yramakrishna/DeepLabCut/conda-environments/Codes/All_vids/Conv_vids/S11adownsampled.mp4':
#   Metadata:
#     major_brand     : M4V
#     minor_version   : 1
#     compatible_brands: M4V mp42isom
#     encoder         : Lavf58.76.100
#   Stream #0:0(eng): Video: h264 (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1280x720 [SAR 10:11 DAR 160:99], q=2-31, 59.94 fps, 60k tbn (default)
#     Metadata:
#       creation_time   : 2019-12-02T10:28:53.000000Z
#       handler_name    : Mainconcept MP4 Video Media Handler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=   69 fps=0.0 q=-1.0 Lsize=     438kB time=00:00:01.10 bitrate=3259.0kbits/s speed=2.86x
# video:436kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.391211%
# [libx264 @ 0x559e085c0c00] frame I:1     Avg QP:23.18  size: 58144
# [libx264 @ 0x559e085c0c00] frame P:18    Avg QP:25.18  size: 13918
# [libx264 @ 0x559e085c0c00] frame B:50    Avg QP:29.33  size:  2749
# [libx264 @ 0x559e085c0c00] consecutive B-frames:  1.4%  5.8%  0.0% 92.8%
# [libx264 @ 0x559e085c0c00] mb I  I16..4:  9.8% 75.5% 14.7%
# [libx264 @ 0x559e085c0c00] mb P  I16..4:  2.6% 11.9%  1.4%  P16..4: 34.9% 10.7%  4.5%  0.0%  0.0%    skip:34.0%
# [libx264 @ 0x559e085c0c00] mb B  I16..4:  0.2%  0.6%  0.0%  B16..8: 32.8%  2.5%  0.4%  direct: 0.8%  skip:62.8%  L0:44.0% L1:52.0% BI: 4.0%
# [libx264 @ 0x559e085c0c00] 8x8 transform intra:75.1% inter:86.1%
# [libx264 @ 0x559e085c0c00] coded y,uvDC,uvAC intra: 58.9% 30.2% 5.5% inter: 7.5% 2.8% 0.1%
# [libx264 @ 0x559e085c0c00] i16 v,h,dc,p: 26% 31%  6% 38%
# [libx264 @ 0x559e085c0c00] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 20% 19% 16%  6%  8%  7%  9%  7%  8%
# [libx264 @ 0x559e085c0c00] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 13% 21% 10%  7% 13%  6% 17%  6%  6%
# [libx264 @ 0x559e085c0c00] i8c dc,h,v,p: 66% 14% 17%  3%
# [libx264 @ 0x559e085c0c00] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x559e085c0c00] ref P L0: 71.0%  9.1% 15.9%  4.0%
# [libx264 @ 0x559e085c0c00] ref B L0: 94.0%  5.5%  0.5%
# [libx264 @ 0x559e085c0c00] ref B L1: 98.4%  1.6%
# [libx264 @ 0x559e085c0c00] kb/s:3100.40
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   WARNING: library configuration mismatch
#   avcodec     configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared --enable-version3 --disable-doc --disable-programs --enable-libaribb24 --enable-libopencore_amrnb --enable-libopencore_amrwb --enable-libtesseract --enable-libvo_amrwbenc --enable-libsmbclient
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/home/yramakrishna/DeepLabCut/conda-environments/Codes/All_vids/Conv_vids/S10b.mp4':
#   Metadata:
#     major_brand     : M4V
#     minor_version   : 1
#     compatible_brands: M4V mp42isom
#     creation_time   : 2019-12-13T07:35:58.000000Z
#   Duration: 00:00:05.67, start: 0.000000, bitrate: 2931 kb/s
#   Stream #0:0(eng): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709), 1920x1080 [SAR 10:11 DAR 160:99], 2920 kb/s, 59.94 fps, 59.94 tbr, 60k tbn, 119.88 tbc (default)
#     Metadata:
#       creation_time   : 2019-12-13T07:35:58.000000Z
#       handler_name    : Mainconcept MP4 Video Media Handler
#       vendor_id       : [0][0][0][0]
#       encoder         : AVC Coding
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x561b90f2f9c0] using SAR=10/11
# [libx264 @ 0x561b90f2f9c0] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x561b90f2f9c0] profile High, level 3.2, 4:2:0, 8-bit
# [libx264 @ 0x561b90f2f9c0] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=22 lookahead_threads=3 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '/home/yramakrishna/DeepLabCut/conda-environments/Codes/All_vids/Conv_vids/S10bdownsampled.mp4':
#   Metadata:
#     major_brand     : M4V
#     minor_version   : 1
#     compatible_brands: M4V mp42isom
#     encoder         : Lavf58.76.100
#   Stream #0:0(eng): Video: h264 (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1280x720 [SAR 10:11 DAR 160:99], q=2-31, 59.94 fps, 60k tbn (default)
#     Metadata:
#       creation_time   : 2019-12-13T07:35:58.000000Z
#       handler_name    : Mainconcept MP4 Video Media Handler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=  340 fps=0.0 q=-1.0 Lsize=     966kB time=00:00:05.62 bitrate=1407.6kbits/s speed=6.25x
# video:961kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.505966%
# [libx264 @ 0x561b90f2f9c0] frame I:2     Avg QP:20.42  size: 83080
# [libx264 @ 0x561b90f2f9c0] frame P:90    Avg QP:21.96  size:  8547
# [libx264 @ 0x561b90f2f9c0] frame B:248   Avg QP:28.85  size:   194
# [libx264 @ 0x561b90f2f9c0] consecutive B-frames:  1.2%  4.1%  1.8% 92.9%
# [libx264 @ 0x561b90f2f9c0] mb I  I16..4:  4.1% 70.6% 25.4%
# [libx264 @ 0x561b90f2f9c0] mb P  I16..4:  0.2%  1.6%  0.1%  P16..4: 23.5%  5.0%  4.6%  0.0%  0.0%    skip:64.9%
# [libx264 @ 0x561b90f2f9c0] mb B  I16..4:  0.0%  0.0%  0.0%  B16..8:  7.2%  0.0%  0.0%  direct: 0.0%  skip:92.8%  L0:15.6% L1:83.8% BI: 0.6%
# [libx264 @ 0x561b90f2f9c0] 8x8 transform intra:76.0% inter:63.8%
# [libx264 @ 0x561b90f2f9c0] coded y,uvDC,uvAC intra: 79.9% 91.7% 63.2% inter: 3.3% 5.9% 0.5%
# [libx264 @ 0x561b90f2f9c0] i16 v,h,dc,p: 10% 27%  8% 54%
# [libx264 @ 0x561b90f2f9c0] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 13% 27% 22%  5%  6%  6%  8%  5%  7%
# [libx264 @ 0x561b90f2f9c0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 16% 37% 11%  5%  6%  5%  9%  6%  6%
# [libx264 @ 0x561b90f2f9c0] i8c dc,h,v,p: 52% 27% 15%  7%
# [libx264 @ 0x561b90f2f9c0] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x561b90f2f9c0] ref P L0: 83.7%  9.0%  6.7%  0.6%
# [libx264 @ 0x561b90f2f9c0] ref B L0: 92.5%  7.3%  0.2%
# [libx264 @ 0x561b90f2f9c0] ref B L1: 94.4%  5.6%
# [libx264 @ 0x561b90f2f9c0] kb/s:1387.18
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   WARNING: library configuration mismatch
#   avcodec     configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared --enable-version3 --disable-doc --disable-programs --enable-libaribb24 --enable-libopencore_amrnb --enable-libopencore_amrwb --enable-libtesseract --enable-libvo_amrwbenc --enable-libsmbclient
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/home/yramakrishna/DeepLabCut/conda-environments/Codes/All_vids/Conv_vids/S10a.mp4':
#   Metadata:
#     major_brand     : M4V
#     minor_version   : 1
#     compatible_brands: M4V mp42isom
#     creation_time   : 2019-12-13T07:38:21.000000Z
#   Duration: 00:00:00.57, start: 0.000000, bitrate: 4247 kb/s
#   Stream #0:0(eng): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709), 1920x1080 [SAR 10:11 DAR 160:99], 4152 kb/s, 59.94 fps, 59.94 tbr, 60k tbn, 119.88 tbc (default)
#     Metadata:
#       creation_time   : 2019-12-13T07:38:21.000000Z
#       handler_name    : Mainconcept MP4 Video Media Handler
#       vendor_id       : [0][0][0][0]
#       encoder         : AVC Coding
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x5613099b2280] using SAR=10/11
# [libx264 @ 0x5613099b2280] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x5613099b2280] profile High, level 3.2, 4:2:0, 8-bit
# [libx264 @ 0x5613099b2280] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=22 lookahead_threads=3 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '/home/yramakrishna/DeepLabCut/conda-environments/Codes/All_vids/Conv_vids/S10adownsampled.mp4':
#   Metadata:
#     major_brand     : M4V
#     minor_version   : 1
#     compatible_brands: M4V mp42isom
#     encoder         : Lavf58.76.100
#   Stream #0:0(eng): Video: h264 (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1280x720 [SAR 10:11 DAR 160:99], q=2-31, 59.94 fps, 60k tbn (default)
#     Metadata:
#       creation_time   : 2019-12-13T07:38:21.000000Z
#       handler_name    : Mainconcept MP4 Video Media Handler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=   34 fps=0.0 q=-1.0 Lsize=     178kB time=00:00:00.51 bitrate=2813.7kbits/s speed=1.88x
# video:176kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.735408%
# [libx264 @ 0x5613099b2280] frame I:1     Avg QP:24.12  size: 43295
# [libx264 @ 0x5613099b2280] frame P:9     Avg QP:25.47  size: 11809
# [libx264 @ 0x5613099b2280] frame B:24    Avg QP:28.03  size:  1263
# [libx264 @ 0x5613099b2280] consecutive B-frames:  5.9%  0.0%  0.0% 94.1%
# [libx264 @ 0x5613099b2280] mb I  I16..4:  9.1% 71.0% 19.9%
# [libx264 @ 0x5613099b2280] mb P  I16..4:  2.3%  3.1%  0.2%  P16..4: 42.5% 11.1%  6.0%  0.0%  0.0%    skip:34.8%
# [libx264 @ 0x5613099b2280] mb B  I16..4:  0.0%  0.0%  0.0%  B16..8: 26.2%  0.7%  0.1%  direct: 0.5%  skip:72.5%  L0:60.2% L1:38.0% BI: 1.9%
# [libx264 @ 0x5613099b2280] 8x8 transform intra:65.8% inter:76.6%
# [libx264 @ 0x5613099b2280] coded y,uvDC,uvAC intra: 52.4% 66.5% 26.3% inter: 5.5% 9.9% 0.1%
# [libx264 @ 0x5613099b2280] i16 v,h,dc,p: 23% 41% 10% 26%
# [libx264 @ 0x5613099b2280] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 19% 34% 18%  3%  5%  5%  8%  3%  5%
# [libx264 @ 0x5613099b2280] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 19% 43%  8%  4%  5%  3%  9%  5%  4%
# [libx264 @ 0x5613099b2280] i8c dc,h,v,p: 53% 28% 14%  6%
# [libx264 @ 0x5613099b2280] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x5613099b2280] ref P L0: 68.9%  9.2% 17.9%  3.9%
# [libx264 @ 0x5613099b2280] ref B L0: 94.5%  4.9%  0.6%
# [libx264 @ 0x5613099b2280] ref B L1: 99.4%  0.6%
# [libx264 @ 0x5613099b2280] kb/s:2537.09
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   WARNING: library configuration mismatch
#   avcodec     configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared --enable-version3 --disable-doc --disable-programs --enable-libaribb24 --enable-libopencore_amrnb --enable-libopencore_amrwb --enable-libtesseract --enable-libvo_amrwbenc --enable-libsmbclient
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/home/yramakrishna/DeepLabCut/conda-environments/Codes/All_vids/Conv_vids/S7b.mp4':
#   Metadata:
#     major_brand     : M4V
#     minor_version   : 1
#     compatible_brands: M4V mp42isom
#     creation_time   : 2019-12-04T09:54:03.000000Z
#   Duration: 00:00:03.53, start: 0.000000, bitrate: 4458 kb/s
# ...
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-06 16:20:23.998030: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-07-06 16:20:23.998167: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-07-06 16:20:23.998290: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-07-06 16:20:24.264964: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-07-06 16:20:24.265122: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-07-06 16:20:24.265262: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-07-06 16:20:24.265343: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13474 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4080, pci bus id: 0000:51:00.0, compute capability: 8.9
# 2023-07-06 16:20:24.282041: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:354] MLIR V1 optimization pass is not enabled
# Analyzing all the videos in the directory...
# Starting to analyze %  /home/yramakrishna/DeepLabCut/conda-environments/Codes/All_vids/DLC-VK-2023-07-06/videos/S10adownsampled_AGC.mp4
# Loading  /home/yramakrishna/DeepLabCut/conda-environments/Codes/All_vids/DLC-VK-2023-07-06/videos/S10adownsampled_AGC.mp4
# Duration of video [s]:  0.58 , recorded with  59.0 fps!
# Overall # of frames:  34  found with (before cropping) frame dimensions:  1280 720
# Starting to extract posture
#   0%|                                                    | 0/34 [00:00<?, ?it/s]2023-07-06 16:20:25.564322: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8800
# 2023-07-06 16:20:25.958822: I tensorflow/stream_executor/cuda/cuda_blas.cc:1614] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 100%|███████████████████████████████████████████| 34/34 [00:07<00:00,  4.85it/s]
# Saving results in /home/yramakrishna/DeepLabCut/conda-environments/Codes/All_vids/DLC-VK-2023-07-06/videos...
# Saving csv poses!
# Starting to analyze %  /home/yramakrishna/DeepLabCut/conda-environments/Codes/All_vids/DLC-VK-2023-07-06/videos/S11adownsampled_AGC.mp4
# Loading  /home/yramakrishna/DeepLabCut/conda-environments/Codes/All_vids/DLC-VK-2023-07-06/videos/S11adownsampled_AGC.mp4
# Duration of video [s]:  1.17 , recorded with  59.0 fps!
# Overall # of frames:  69  found with (before cropping) frame dimensions:  1280 720
# Starting to extract posture
# 100%|███████████████████████████████████████████| 69/69 [00:02<00:00, 29.99it/s]
# Saving results in /home/yramakrishna/DeepLabCut/conda-environments/Codes/All_vids/DLC-VK-2023-07-06/videos...
# Saving csv poses!
# Starting to analyze %  /home/yramakrishna/DeepLabCut/conda-environments/Codes/All_vids/DLC-VK-2023-07-06/videos/S7adownsampled_AGC.mp4
# Loading  /home/yramakrishna/DeepLabCut/conda-environments/Codes/All_vids/DLC-VK-2023-07-06/videos/S7adownsampled_AGC.mp4
# Duration of video [s]:  1.07 , recorded with  30.0 fps!
# Overall # of frames:  32  found with (before cropping) frame dimensions:  1280 720
# Starting to extract posture
# 100%|███████████████████████████████████████████| 32/32 [00:00<00:00, 36.16it/s]
# Saving results in /home/yramakrishna/DeepLabCut/conda-environments/Codes/All_vids/DLC-VK-2023-07-06/videos...
# Saving csv poses!
# Starting to analyze %  /home/yramakrishna/DeepLabCut/conda-environments/Codes/All_vids/DLC-VK-2023-07-06/videos/S68downsampled_AGC.mp4
# Loading  /home/yramakrishna/DeepLabCut/conda-environments/Codes/All_vids/DLC-VK-2023-07-06/videos/S68downsampled_AGC.mp4
# Duration of video [s]:  2.69 , recorded with  59.0 fps!
# Overall # of frames:  159  found with (before cropping) frame dimensions:  1280 720
# Starting to extract posture
# 100%|█████████████████████████████████████████| 159/159 [00:03<00:00, 43.56it/s]
# Saving results in /home/yramakrishna/DeepLabCut/conda-environments/Codes/All_vids/DLC-VK-2023-07-06/videos...
# Saving csv poses!
# Starting to analyze %  /home/yramakrishna/DeepLabCut/conda-environments/Codes/All_vids/DLC-VK-2023-07-06/videos/S76bdownsampled_AGC.mp4
# Loading  /home/yramakrishna/DeepLabCut/conda-environments/Codes/All_vids/DLC-VK-2023-07-06/videos/S76bdownsampled_AGC.mp4
# Duration of video [s]:  4.43 , recorded with  30.0 fps!
# Overall # of frames:  133  found with (before cropping) frame dimensions:  1280 720
# Starting to extract posture
# 100%|█████████████████████████████████████████| 133/133 [00:03<00:00, 42.04it/s]
# Saving results in /home/yramakrishna/DeepLabCut/conda-environments/Codes/All_vids/DLC-VK-2023-07-06/videos...
# Saving csv poses!
# Starting to analyze %  /home/yramakrishna/DeepLabCut/conda-environments/Codes/All_vids/DLC-VK-2023-07-06/videos/S10bdownsampled_AGC.mp4
# Loading  /home/yramakrishna/DeepLabCut/conda-environments/Codes/All_vids/DLC-VK-2023-07-06/videos/S10bdownsampled_AGC.mp4
# Duration of video [s]:  5.76 , recorded with  59.0 fps!
# Overall # of frames:  340  found with (before cropping) frame dimensions:  1280 720
# Starting to extract posture
# 100%|█████████████████████████████████████████| 340/340 [00:07<00:00, 44.49it/s]
# Saving results in /home/yramakrishna/DeepLabCut/conda-environments/Codes/All_vids/DLC-VK-2023-07-06/videos...
# Saving csv poses!
# Starting to analyze %  /home/yramakrishna/DeepLabCut/conda-environments/Codes/All_vids/DLC-VK-2023-07-06/videos/S11bdownsampled_AGC.mp4
# Loading  /home/yramakrishna/DeepLabCut/conda-environments/Codes/All_vids/DLC-VK-2023-07-06/videos/S11bdownsampled_AGC.mp4
# Duration of video [s]:  3.9 , recorded with  59.0 fps!
# Overall # of frames:  230  found with (before cropping) frame dimensions:  1280 720
# Starting to extract posture
# 100%|█████████████████████████████████████████| 230/230 [00:05<00:00, 43.35it/s]
# Saving results in /home/yramakrishna/DeepLabCut/conda-environments/Codes/All_vids/DLC-VK-2023-07-06/videos...
# Saving csv poses!
# Starting to analyze %  /home/yramakrishna/DeepLabCut/conda-environments/Codes/All_vids/DLC-VK-2023-07-06/videos/S7bdownsampled_AGC.mp4
# Loading  /home/yramakrishna/DeepLabCut/conda-environments/Codes/All_vids/DLC-VK-2023-07-06/videos/S7bdownsampled_AGC.mp4
# Duration of video [s]:  3.53 , recorded with  30.0 fps!
# Overall # of frames:  106  found with (before cropping) frame dimensions:  1280 720
# Starting to extract posture
# 100%|█████████████████████████████████████████| 106/106 [00:02<00:00, 40.64it/s]
# Saving results in /home/yramakrishna/DeepLabCut/conda-environments/Codes/All_vids/DLC-VK-2023-07-06/videos...
# Saving csv poses!
# Starting to analyze %  /home/yramakrishna/DeepLabCut/conda-environments/Codes/All_vids/DLC-VK-2023-07-06/videos/S76adownsampled_AGC.mp4
# Loading  /home/yramakrishna/DeepLabCut/conda-environments/Codes/All_vids/DLC-VK-2023-07-06/videos/S76adownsampled_AGC.mp4
# Duration of video [s]:  1.33 , recorded with  30.0 fps!
# Overall # of frames:  40  found with (before cropping) frame dimensions:  1280 720
# Starting to extract posture
# 100%|███████████████████████████████████████████| 40/40 [00:01<00:00, 37.84it/s]
# Saving results in /home/yramakrishna/DeepLabCut/conda-environments/Codes/All_vids/DLC-VK-2023-07-06/videos...
# Saving csv poses!
# The videos are analyzed. Now your research can truly start!
#  You can create labeled videos with 'create_labeled_video'
# If the tracking is not satisfactory for some videos, consider expanding the training set. You can use the function 'extract_outlier_frames' to extract a few representative outlier frames.
# Filtering with median model /home/yramakrishna/DeepLabCut/conda-environments/Codes/All_vids/DLC-VK-2023-07-06/videos/S76adownsampled_AGC.mp4
# Saving filtered csv poses!
# Filtering with median model /home/yramakrishna/DeepLabCut/conda-environments/Codes/All_vids/DLC-VK-2023-07-06/videos/S11adownsampled_AGC.mp4
# Saving filtered csv poses!
# Filtering with median model /home/yramakrishna/DeepLabCut/conda-environments/Codes/All_vids/DLC-VK-2023-07-06/videos/S7bdownsampled_AGC.mp4
# Saving filtered csv poses!
# Filtering with median model /home/yramakrishna/DeepLabCut/conda-environments/Codes/All_vids/DLC-VK-2023-07-06/videos/S11bdownsampled_AGC.mp4
# Saving filtered csv poses!
# Filtering with median model /home/yramakrishna/DeepLabCut/conda-environments/Codes/All_vids/DLC-VK-2023-07-06/videos/S10bdownsampled_AGC.mp4
# Saving filtered csv poses!
# Filtering with median model /home/yramakrishna/DeepLabCut/conda-environments/Codes/All_vids/DLC-VK-2023-07-06/videos/S68downsampled_AGC.mp4
# Saving filtered csv poses!
# Filtering with median model /home/yramakrishna/DeepLabCut/conda-environments/Codes/All_vids/DLC-VK-2023-07-06/videos/S76bdownsampled_AGC.mp4
# Saving filtered csv poses!
# Filtering with median model /home/yramakrishna/DeepLabCut/conda-environments/Codes/All_vids/DLC-VK-2023-07-06/videos/S7adownsampled_AGC.mp4
# Saving filtered csv poses!
# Filtering with median model /home/yramakrishna/DeepLabCut/conda-environments/Codes/All_vids/DLC-VK-2023-07-06/videos/S10adownsampled_AGC.mp4
# Saving filtered csv poses!
# Starting to process video: /home/yramakrishna/DeepLabCut/conda-environments/Codes/All_vids/DLC-VK-2023-07-06/videos/S11adownsampled_AGC.mp4Starting to process video: /home/yramakrishna/DeepLabCut/conda-environments/Codes/All_vids/DLC-VK-2023-07-06/videos/S76adownsampled_AGC.mp4Starting to process video: /home/yramakrishna/DeepLabCut/conda-environments/Codes/All_vids/DLC-VK-2023-07-06/videos/S11bdownsampled_AGC.mp4Starting to process video: /home/yramakrishna/DeepLabCut/conda-environments/Codes/All_vids/DLC-VK-2023-07-06/videos/S7bdownsampled_AGC.mp4Starting to process video: /home/yramakrishna/DeepLabCut/conda-environments/Codes/All_vids/DLC-VK-2023-07-06/videos/S10bdownsampled_AGC.mp4Starting to process video: /home/yramakrishna/DeepLabCut/conda-environments/Codes/All_vids/DLC-VK-2023-07-06/videos/S68downsampled_AGC.mp4Starting to process video: /home/yramakrishna/DeepLabCut/conda-environments/Codes/All_vids/DLC-VK-2023-07-06/videos/S76bdownsampled_AGC.mp4Starting to process video: /home/yramakrishna/DeepLabCut/conda-environments/Codes/All_vids/DLC-VK-2023-07-06/videos/S10adownsampled_AGC.mp4Starting to process video: /home/yramakrishna/DeepLabCut/conda-environments/Codes/All_vids/DLC-VK-2023-07-06/videos/S7adownsampled_AGC.mp4
#
#
# Loading /home/yramakrishna/DeepLabCut/conda-environments/Codes/All_vids/DLC-VK-2023-07-06/videos/S11adownsampled_AGC.mp4 and data.
#
#
# Loading /home/yramakrishna/DeepLabCut/conda-environments/Codes/All_vids/DLC-VK-2023-07-06/videos/S76adownsampled_AGC.mp4 and data.
#
# Loading /home/yramakrishna/DeepLabCut/conda-environments/Codes/All_vids/DLC-VK-2023-07-06/videos/S11bdownsampled_AGC.mp4 and data.
#
# Loading /home/yramakrishna/DeepLabCut/conda-environments/Codes/All_vids/DLC-VK-2023-07-06/videos/S10bdownsampled_AGC.mp4 and data.Loading /home/yramakrishna/DeepLabCut/conda-environments/Codes/All_vids/DLC-VK-2023-07-06/videos/S7bdownsampled_AGC.mp4 and data.Loading /home/yramakrishna/DeepLabCut/conda-environments/Codes/All_vids/DLC-VK-2023-07-06/videos/S68downsampled_AGC.mp4 and data.
# Loading /home/yramakrishna/DeepLabCut/conda-environments/Codes/All_vids/DLC-VK-2023-07-06/videos/S10adownsampled_AGC.mp4 and data.Loading /home/yramakrishna/DeepLabCut/conda-environments/Codes/All_vids/DLC-VK-2023-07-06/videos/S76bdownsampled_AGC.mp4 and data.
# Loading /home/yramakrishna/DeepLabCut/conda-environments/Codes/All_vids/DLC-VK-2023-07-06/videos/S7adownsampled_AGC.mp4 and data.
#
#
#
#
#
# Duration of video [s]: 1.33, recorded with 30.0 fps!Duration of video [s]: 1.17, recorded with 59.0 fps!Duration of video [s]: 3.53, recorded with 30.0 fps!
#
# Duration of video [s]: 3.9, recorded with 59.0 fps!
# Overall # of frames: 69 with cropped frame dimensions: 1280 720Overall # of frames: 40 with cropped frame dimensions: 1280 720
# Overall # of frames: 106 with cropped frame dimensions: 1280 720
#
# Overall # of frames: 230 with cropped frame dimensions: 1280 720
# Generating frames and creating video.Generating frames and creating video.
#
# Generating frames and creating video.Duration of video [s]: 2.69, recorded with 59.0 fps!Duration of video [s]: 0.58, recorded with 59.0 fps!Duration of video [s]: 4.43, recorded with 30.0 fps!Duration of video [s]: 1.07, recorded with 30.0 fps!
# Duration of video [s]: 5.76, recorded with 59.0 fps!Generating frames and creating video.
#
#
#
#
#
#
# Overall # of frames: 34 with cropped frame dimensions: 1280 720Overall # of frames: 159 with cropped frame dimensions: 1280 720Overall # of frames: 32 with cropped frame dimensions: 1280 720Overall # of frames: 133 with cropped frame dimensions: 1280 720Overall # of frames: 340 with cropped frame dimensions: 1280 720
#   0%|                                                    | 0/40 [00:00<?, ?it/s]
# Generating frames and creating video.Generating frames and creating video.
#   0%|                                                    | 0/69 [00:00<?, ?it/s]
# Generating frames and creating video.Generating frames and creating video.Generating frames and creating video.
#   0%|                                                   | 0/106 [00:00<?, ?it/s]
# 100%|██████████████████████████████████████████| 34/34 [00:00<00:00, 161.84it/s]
# 100%|██████████████████████████████████████████| 32/32 [00:00<00:00, 147.58it/s]
# 100%|██████████████████████████████████████████| 40/40 [00:00<00:00, 156.85it/s]
# 100%|██████████████████████████████████████████| 69/69 [00:00<00:00, 177.42it/s]
# 100%|████████████████████████████████████████| 106/106 [00:00<00:00, 237.48it/s]
# 100%|████████████████████████████████████████| 133/133 [00:00<00:00, 264.44it/s]
# 100%|████████████████████████████████████████| 159/159 [00:00<00:00, 211.39it/s]
# 100%|████████████████████████████████████████| 230/230 [00:00<00:00, 268.40it/s]
# 100%|████████████████████████████████████████| 340/340 [00:01<00:00, 303.42it/s]
# Starting Cropping
# Output file written -  Crpoutput_videoS11adownsampled_AGCDLC_resnet50_DLCJul6shuffle1_1030000_filtered_labeled.mp4
# Done5
# Starting Cropping
# Output file written -  Crpoutput_videoS76bdownsampled_AGCDLC_resnet50_DLCJul6shuffle1_1030000_filtered_labeled.mp4
# Done5
# Starting Cropping
# Output file written -  Crpoutput_videoS7adownsampled_AGCDLC_resnet50_DLCJul6shuffle1_1030000_filtered_labeled.mp4
# Done8
# Starting Cropping
# Output file written -  Crpoutput_videoS7bdownsampled_AGCDLC_resnet50_DLCJul6shuffle1_1030000_filtered_labeled.mp4
# Done6
# Starting Cropping
# Output file written -  Crpoutput_videoS11bdownsampled_AGCDLC_resnet50_DLCJul6shuffle1_1030000_filtered_labeled.mp4
# Done7
# Starting Cropping
# Output file written -  Crpoutput_videoS10adownsampled_AGCDLC_resnet50_DLCJul6shuffle1_1030000_filtered_labeled.mp4
# Done6
# Starting Cropping
# Output file written -  Crpoutput_videoS76adownsampled_AGCDLC_resnet50_DLCJul6shuffle1_1030000_filtered_labeled.mp4
# Done
# Starting Cropping
# Output file written -  Crpoutput_videoS68downsampled_AGCDLC_resnet50_DLCJul6shuffle1_1030000_filtered_labeled.mp4
# Done7
# Starting Cropping
# Output file written -  Crpoutput_videoS10bdownsampled_AGCDLC_resnet50_DLCJul6shuffle1_1030000_filtered_labeled.mp4
# Done1
